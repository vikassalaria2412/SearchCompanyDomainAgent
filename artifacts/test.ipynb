# %%
import os
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')

# %%
web_search_tool = TavilySearchResults(TAVILY_API_KEY=TAVILY_API_KEY,\
    description="As an AI Search Engine, search all the web and provide correct URLs for information related to the company name provided as input. You are expected to provide correct URLs that contain information about the given company's subsidiaries and associated domains. Focus on reputable sources such as company websites, business directories, news articles, and other relevant online resources. Search the web for accurate and up-to-date information about the company provided in query. Provide reliable URLs containing information on: 1. The company's subsidiaries 2. Associated domains and websites owned by the company. Focus on reputable sources such as: - Official company websites - Business directories (e.g., Bloomberg, Reuters) - Financial news websites - Industry-specific publications - Government databases (e.g., SEC filings for public companies). Prioritize recent and authoritative sources. Exclude unofficial blogs, personal websites, or unreliable sources. Provide a brief summary of what each URL contains, focusing on its relevance to the company's subsidiaries and associated domains.",\
        max_results=10,include_answer=True,include_images=True)

# %%
company_name = 'Google'

# %%
web_results = web_search_tool.invoke({"query": f"Search for and provide reliable web links containing information about subsidiaries and associated domains of the company: {company_name}. Focus on authoritative sources such as official company websites, business directories, and reputable news outlets. For each link, briefly summarize its relevance to the company's subsidiaries or associated domains."})

# %%
web_results
# Out:
# [{'url': 'https://cloud.google.com/resource-manager/docs/managing-multiple-orgs',
#   'content': 'Each Google Workspace or Cloud Identity account is also associated with a primary domain, such as example.com . For details on using multiple domains, see Add\xa0...Missing:  subsidiaries | Show results with:subsidiaries'},
#  {'url': 'https://icannwiki.org/Google',
#   'content': "May 31, 2022 · Based on ICANN's List of New gTLD Applied-For Strings, Google applied for 101 new gTLDs through its wholly-owned subsidiary, Charleston Road\xa0..."},
#  {'url': 'http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf',
#   'content': 'For example, bill@subsidiary.com could have the email alias bill@parent.com — as long as someone else does not already have that email address.'},
#  {'url': 'https://en.wikipedia.org/wiki/Alphabet_Inc.',
#   'content': 'He clarified that, as a result of the new holding company, Google would be "a bit slimmed down, with the companies that are pretty far afield of our main internet products contained in Alphabet instead".[16] He further stated that the motivation behind the reorganization is to make Google "cleaner and more accountable and better" and that that he wanted to improve "the transparency and oversight of what we\'re doing".[4][8]\nFormer executive Eric Schmidt (now Technical Advisor) revealed in the conference in 2017 the inspiration for this structure came from Warren Buffett and his management structure of Berkshire Hathaway a decade ago.[17] In November 2021, Alphabet announced a new company named Isomorphic Labs, using artificial intelligence for drug discovery and headed by DeepMind CEO Demis Hassabis.[37]\nSenior leadership\nSource:[38]\nList of former board chairs\nList of former chief executives\nCorporate identity\nPage explained the origin of the company\'s name:[16]\nWe liked the name Alphabet because it means a collection of letters that represent language, one of humanity\'s most important innovations, and is the core of how we index with Google search! The lawsuit was settled in February 2018, with Uber agreeing not to use the self-driving technology in dispute and also agreed to provide Waymo with an equity stake of 0.34%, equating to around $245\xa0million at the firm\'s early 2018 value.[59]\nIn October 2018, a class action lawsuit was filed against Google and Alphabet due to "non-public" Google+ account data being exposed as a result of a privacy bug that allowed app developers to gain access to the private information of users. "[22]\nStructure\nAlphabet Inc. is the parent of a diverse set of subsidiaries:[23][24][25]\nTekedra Mawakana\nAs of September\xa01, 2017[update], their equity is held by a subsidiary known as XXVI Holdings, Inc. (referring to the Roman numeral of 26, the number of letters in the alphabet), so that they can be valued and legally separated from Google. Experts cited Apple\'s lack of innovation as well as increasing Chinese competition as reasons for the poor performance.[49][50]\nAs of 2019[update], Alphabet is ranked No. 15 on the Fortune 500 rankings of the largest United States corporations by total revenue.[51]\nOn January 16, 2020, Alphabet became the fourth US company to reach a $1 trillion market value[52] entering the trillion dollar companies club for the first time.\n'},
#  {'url': 'https://en.wikipedia.org/wiki/Google',
#   'content': '"[341][342][343] The contract has been criticized by shareholders as well as their employees over concerns that the project will lead to further abuses of Palestinians\' human rights in the context of the ongoing illegal occupation and the Israeli–Palestinian conflict.[344][345] Ariel Koren, a former marketing manager for Google\'s educational products and an outspoken critic of the project, wrote that Google "systematically silences Palestinian, Jewish, Arab and Muslim voices concerned about Google\'s complicity in violations of Palestinian human rights—to the point of formally retaliating against workers and creating an environment of fear", reflecting her view that the ultimatum came in retaliation for her opposition to and organization against the project.[341][346]\nAnti-trust, privacy, and other litigation\nOn June 27, 2017, the company received a record fine of €2.42 billion from the European Union for "promoting its own shopping comparison service at the top of search results. Upon completion of the restructuring, Sundar Pichai became CEO of Google, replacing Larry Page, who became CEO of Alphabet.[95][96][97]\nOn August 8, 2017, Google fired employee James Damore after he distributed a memo throughout the company that argued bias and "Google\'s Ideological Echo Chamber" clouded their thinking about diversity and inclusion, and that it is also biological factors, not discrimination alone, that cause the average woman to be less interested than men in technical positions.[98] Google CEO Sundar Pichai accused Damore of violating company policy by "advancing harmful gender stereotypes in our workplace", and he was fired on the same day.[99][100][101]\nBetween 2018 and 2019, tensions between the company\'s leadership and its workers escalated as staff protested company decisions on internal sexual harassment, Dragonfly, a censored Chinese search engine, and Project Maven, a military drone artificial intelligence, which had been seen as areas of revenue growth for the company.[102][103] On October 25, 2018, The New York Times published the exposé, "How Google Protected Andy Rubin, the \'Father of Android\'". In 2007, Google announced a free Internet service called TiSP, or Toilet Internet Service Provider, where one obtained a connection by flushing one end of a fiber-optic cable down their toilet.[221]\nGoogle\'s services contain easter eggs, such as the Swedish Chef\'s "Bork bork bork," Pig Latin, "Hacker" or leetspeak, Elmer Fudd, Pirate, and Klingon as language selections for its search engine.[222] When searching for the word "anagram," meaning a rearrangement of letters from one word to form other valid words, Google\'s suggestion feature displays "Did you mean: nag a ram?"[223] Since 2019, Google runs free online courses to help engineers learn how to plan and author technical documentation better.[224]\nWorkplace culture\nOn Fortune magazine\'s list of the best companies to work for, Google ranked first in 2007, 2008 and 2012,[225][226][227] and fourth in 2009 and 2010.[228][229] In July 2013, Google introduced the Chromecast dongle, which allows users to stream content from their smartphones to televisions.[171][172]\nIn June 2014, Google announced Google Cardboard, a simple cardboard viewer that lets the user place their smartphone in a special front compartment to view virtual reality (VR) media.[173]\nOther hardware products include:\nEnterprise services\nGoogle Workspace (formerly G Suite until October 2020[176]) is a monthly subscription offering for organizations and businesses to get access to a collection of Google\'s services, including Gmail, Google Drive and Google Docs, Google Sheets and Google Slides, with additional administrative tools, unique domain names, and 24/7 support.[177]\nOn September 24, 2012,[178] Google Earth, launched in 2005, allowed users to see high-definition satellite pictures from all over the world for free through a client software downloaded to their computers.[159 ...
#  {'url': 'https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en',
#   'content': 'Oct 2, 2020 · Eligible nonprofits can only have one Google for Nonprofits account and associated suite of products- in this case one G Suite account. If you\xa0...'},
#  {'url': 'https://www.investopedia.com/investing/companies-owned-by-google/',
#   'content': "7 Companies Owned by Google (Alphabet)\nSmart-home products, ad management, cybersecurity, and more\nPete Rathburn is a copy editor and fact-checker with expertise in economics and personal finance and over twenty years of experience in the classroom.\n As part of our effort to improve the awareness of the importance of diversity in companies, we have highlighted the transparency of Google's (Alphabet's) commitment to diversity, inclusiveness, and social responsibility. DoubleClick\nDoubleClick was founded in 1996 and became one of the stock-market stars of the dot-com era as a leader in the first generation of online advertising during the 1990s. Google closed the Fitbit buyout in January 2021 after the deal was first announced in November 2019, adding to its wearable-device lineup following its acquisition of the Timex smartwatch technology in 2019.\n In 2014, Google acquired Nest and has since merged it with Google's Home division to create Google Nest, which offers a range of smart home products, including security alarm systems, security cameras, Wifi routers, and home assistance devices.\n"},
#  {'url': 'https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1',
#   'content': 'Nov 18, 2020 · First step when on-boarding an enterprise in Google Cloud is to set up Cloud Identity or Google Workspace to centrally manage Google Cloud.'},
#  {'url': 'https://support.google.com/a/answer/12099366?hl=en',
#   'content': 'Sign up for a new Google Workspace account with a domain or subdomain that you own, such as temp.example.com. The domain acts as a placeholder until you switch\xa0...'},
#  {'url': 'https://cloud.google.com/architecture/identity/best-practices-for-planning',
#   'content': 'Jun 26, 2024 · This document presents best practices for deciding how many Cloud Identity or Google Workspace accounts, Google Cloud organizations,\xa0...'}]

# %%
web_result_tavily_url = [result['url'] for result in web_results]

# %%
web_result_tavily_url
# Out:
# ['https://cloud.google.com/resource-manager/docs/managing-multiple-orgs',
#  'https://icannwiki.org/Google',
#  'http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf',
#  'https://en.wikipedia.org/wiki/Alphabet_Inc.',
#  'https://en.wikipedia.org/wiki/Google',
#  'https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en',
#  'https://www.investopedia.com/investing/companies-owned-by-google/',
#  'https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1',
#  'https://support.google.com/a/answer/12099366?hl=en',
#  'https://cloud.google.com/architecture/identity/best-practices-for-planning']

# %%
# write in json
import json
with open('web_result_tavily_url_latest.json', 'w') as f:
    json.dump(web_results, f)

# %%
# Perplexity web search for subsidiaries and associated domains
import os
PPLX_API_KEY = os.getenv('PERPLEXITY_API_KEY')

# %%
from langchain_community.chat_models import ChatPerplexity
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
chat = ChatPerplexity(
    temperature=0, pplx_api_key=PPLX_API_KEY, model="llama-3-sonar-small-32k-online"
)

# %%
system = "As an AI Search Engine, search the entire web and provide correct URLs for information related \
    to the company name provided as input. You are expected to provide correct URLs\
    that contain information about the given company's subsidiaries and associated domains.\
    Focus on reputable sources such as company websites, business directories,\
    news articles, and other relevant online resources.\
    Search the web for accurate and up-to-date information about the company provided in query.\
    Provide reliable URLs containing information on:\
    1. The company's subsidiaries\
    2. Associated domains and websites owned by the company.\
    Focus on reputable sources such as: \
    - Official company websites - Business directories (e.g., Bloomberg, Reuters)\
    - Financial news websites\
    - Industry-specific publications\
    - Government databases (e.g., SEC filings for public companies).\
    Prioritize recent and authoritative sources.\
    Exclude unofficial blogs, personal websites, or unreliable sources.\
    Provide a brief summary of what each URL contains,\
    focusing on its relevance to the company's subsidiaries and associated domains."
human = "{input}"
prompt = ChatPromptTemplate.from_messages([("system", system), ("human", human)])

chain = prompt | chat | StrOutputParser()
perplexity_web_response = chain.invoke({"input": f"Search for and provide reliable web links\
                                    containing information about subsidiaries\
                                    and associated domains of the company: {company_name}.\
                                    Focus on authoritative sources such as official company websites,\
                                    business directories, and reputable news outlets.\
                                    For each link, briefly summarize its relevance to the company's\
                                    subsidiaries or associated domains."})

# %%
perplexity_web_response
# Out:
# "To find reliable web links containing information about subsidiaries and associated domains of Google, I searched authoritative sources such as official company websites, business directories, and reputable news outlets. Here are the results:\n\n1. **Google's Official Website**\n   - **URL:** https://www.google.com\n   - **Summary:** Google's official website provides information about the company's products and services, including search engines, Google Maps, Google Drive, and other applications. It also includes details about Google's subsidiaries and associated domains.\n\n2. **Google's Subsidiaries**\n   - **URL:** https://www.google.com/about/subsidiaries/\n   - **Summary:** This page lists Google's subsidiaries, including Alphabet Inc., Google Cloud, Google Fiber, Google Ventures, and Google Capital. It provides details about each subsidiary's role and services.\n\n3. **Google's Associated Domains**\n   - **URL:** https://www.google.com/about/our-company/associated-companies/\n   - **Summary:** This page lists Google's associated companies, including YouTube, Android, and other platforms. It provides information about how these domains are related to Google's core services and products.\n\n4. **Google's Business Directory Listings**\n   - **URL:** https://www.bloomberg.com/profile/company/1253793D\n   - **Summary:** Bloomberg's profile of Google includes information about the company's subsidiaries and associated domains. It provides financial data and details about Google's business operations.\n\n5. **Google's News and Updates**\n   - **URL:** https://www.reuters.com/technology/google\n   - **Summary:** Reuters' technology section covers news and updates about Google, including information about its subsidiaries and associated domains. It provides insights into Google's latest developments and impact on the technology industry.\n\nThese links provide comprehensive information about Google's subsidiaries and associated domains, sourced from official company websites, business directories, and reputable news outlets."

# %%
with open('perplexity_web_response_latest.json', 'w') as f:
    json.dump(perplexity_web_response, f)

# %%
#response.content

# %%
OPENAI_API_KEY=os.getenv('OPENAI_API_KEY')

# %%
#print(OPENAI_API_KEY)

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(api_key=OPENAI_API_KEY)

# %%
openai_model='gpt-4o'

# %%
from langchain_core.prompts import ChatPromptTemplate

system = """
You are an AI Content Extractor. Your job is to extract urls with the summary as text.
Return the information in the following list format:
[
    {
        "url": "https://www.test.com",
        "summary": "This is a summary of the content in the website"
    },
    {
        "url": "https://www.test1.com",
        "summary": "This is a summary of the content in the website"
    }
]
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "{system}"),
        ("human", "Response is :{response}"),
    ]
)

llm = ChatOpenAI(model=openai_model, temperature=0)
chain = prompt | llm | StrOutputParser()

openai_perplexity_response = chain.invoke(
    {
        "system": system,
        "response": perplexity_web_response
    }
    
)

# %%
openai_perplexity_response
# Out:
# '[\n    {\n        "url": "https://www.google.com",\n        "summary": "Google\'s official website provides information about the company\'s products and services, including search engines, Google Maps, Google Drive, and other applications. It also includes details about Google\'s subsidiaries and associated domains."\n    },\n    {\n        "url": "https://www.google.com/about/subsidiaries/",\n        "summary": "This page lists Google\'s subsidiaries, including Alphabet Inc., Google Cloud, Google Fiber, Google Ventures, and Google Capital. It provides details about each subsidiary\'s role and services."\n    },\n    {\n        "url": "https://www.google.com/about/our-company/associated-companies/",\n        "summary": "This page lists Google\'s associated companies, including YouTube, Android, and other platforms. It provides information about how these domains are related to Google\'s core services and products."\n    },\n    {\n        "url": "https://www.bloomberg.com/profile/company/1253793D",\n        "summary": "Bloomberg\'s profile of Google includes information about the company\'s subsidiaries and associated domains. It provides financial data and details about Google\'s business operations."\n    },\n    {\n        "url": "https://www.reuters.com/technology/google",\n        "summary": "Reuters\' technology section covers news and updates about Google, including information about its subsidiaries and associated domains. It provides insights into Google\'s latest developments and impact on the technology industry."\n    }\n]'

# %%
perplexity_web_result = json.loads(openai_perplexity_response)
final_perplexity_urls = [result['url'] for result in perplexity_web_result]

# %%
final_perplexity_urls
# Out:
# ['https://www.google.com',
#  'https://www.google.com/about/subsidiaries/',
#  'https://www.google.com/about/our-company/associated-companies/',
#  'https://www.bloomberg.com/profile/company/1253793D',
#  'https://www.reuters.com/technology/google']

# %%
fial_web_scrapping_urls = list(set(web_result_tavily_url) | set(final_perplexity_urls))

# %%
fial_web_scrapping_urls
# Out:
# ['https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en',
#  'https://www.google.com',
#  'https://en.wikipedia.org/wiki/Google',
#  'https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1',
#  'https://www.reuters.com/technology/google',
#  'https://www.google.com/about/our-company/associated-companies/',
#  'https://en.wikipedia.org/wiki/Alphabet_Inc.',
#  'https://www.bloomberg.com/profile/company/1253793D',
#  'https://www.google.com/about/subsidiaries/',
#  'https://cloud.google.com/resource-manager/docs/managing-multiple-orgs',
#  'https://cloud.google.com/architecture/identity/best-practices-for-planning',
#  'https://support.google.com/a/answer/12099366?hl=en',
#  'http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf',
#  'https://icannwiki.org/Google',
#  'https://www.investopedia.com/investing/companies-owned-by-google/']

# %%
# from langchain.retrievers.web_research import WebResearchRetriever
# from langchain_chroma import Chroma
# from langchain_community.utilities import GoogleSearchAPIWrapper
# from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# %%
# # Vectorstore
# vectorstore = Chroma(
#     embedding_function=OpenAIEmbeddings(), persist_directory="./chroma_db_oai"
# )

# # LLM
# # llm = ChatOpenAI(temperature=0)

# # Search
# search = GoogleSearchAPIWrapper()

# %%
# Web scrapping using Crawl4AI
# from crawl4ai import WebCrawler

# # Create an instance of WebCrawler
# crawler = WebCrawler()
# # Warm up the crawler (load necessary models)
# crawler.warmup()

# %%
# consolidated_context_list = []
# for url in fial_web_scrapping_urls:
#     result = crawler.run(url=url)
#     consolidated_context_list.append(result.markdown)

# %%
# consolidated_context_list

# %%
# result_check=crawler.run(url="https://en.wikipedia.org/wiki/Google")

# %%
# result.markdown

# %%
from crawl4ai import WebCrawler

# Create an instance of WebCrawler
crawler = WebCrawler()

# Warm up the crawler (load necessary models)
crawler.warmup()

# # Run the crawler on a URL
# result = crawler.run(url="https://openai.com/api/pricing/")

# # Print the extracted content
# print(result.markdown)
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
# import os
# from crawl4ai import WebCrawler
# from crawl4ai.extraction_strategy import LLMExtractionStrategy
# from pydantic import BaseModel, Field

# class OpenAIModelInfoExtractor(BaseModel):
#     model_name: str = Field(..., description="Subsidiaries and Associated Domains Extractor")
#     input_data: str = Field(..., description="Extract subsidiaries and associated domains of the company.")
#     output_data: str = Field(..., description="Output as Extracted subsidiaries and associated domains of the company.")

# url = 'https://www.investopedia.com/investing/companies-owned-by-google/'
# crawler = WebCrawler()
# crawler.warmup()

# result = crawler.run(
#         url=url,
#         word_count_threshold=1,
#         extraction_strategy= LLMExtractionStrategy(
#             provider= "openai/gpt-4o", api_token = os.getenv('OPENAI_API_KEY'),
#             schema=OpenAIModelInfoExtractor.schema(),
#             extraction_type="schema",
#             instruction="""Extract the subsidiaries and associated domains of the company .Extracted model JSON format should look like this: 
#             {"subsidiaries":["subsidiaries1","subsidiaries2",...], "associated_domains": ["associated_domain_1","associated_domain_2",....]}."""
#         ),            
#         bypass_cache=True,
#     )

# print(result.extracted_content)

# %%
# type(result.extracted_content)

# %%
import os
from crawl4ai import WebCrawler
from crawl4ai.extraction_strategy import LLMExtractionStrategy
from pydantic import BaseModel, Field
crawler = WebCrawler()
crawler.warmup()
consolidated_crawl4ai_context_list = []

class OpenAIModelInfoExtractor(BaseModel):
    model_name: str = Field(..., description="Subsidiaries and Associated Domains Extractor")
    input_data: str = Field(..., description="Extract subsidiaries and associated domains of the company.")
    output_data: str = Field(..., description="Output as Extracted subsidiaries and associated domains of the company.")

# run each loop against final_web_scrapping_urls

for url in fial_web_scrapping_urls:
    result = crawler.run(
        url=url,
        word_count_threshold=1,
        extraction_strategy= LLMExtractionStrategy(
            provider= "openai/gpt-4o", api_token = os.getenv('OPENAI_API_KEY'),
            schema=OpenAIModelInfoExtractor.schema(),
            extraction_type="schema",
            instruction="""Extract the subsidiaries and associated domains of the company .Extracted model JSON format should look like this: 
            {"subsidiaries":["subsidiaries1","subsidiaries2",...], "associated_domains": ["associated_domain_1","associated_domain_2",....]}."""
            ),            
            bypass_cache=True,
        )

    consolidated_crawl4ai_context_list.append(result.extracted_content)
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl
# [LOG] 🚀 Crawling done for https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en, success: True, time taken: 4.100951194763184 seconds
# [LOG] 🚀 Content extracted for https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en, success: True, time taken: 0.06629085540771484 seconds
# [LOG] 🔥 Extracting semantic blocks for https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en - block index: 0
# [LOG] Extracted 1 blocks from URL: https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en block index: 0
# [LOG] 🚀 Extraction done for https://support.google.com/nonprofits/thread/74557231/g-suite-legacy-free-to-g-suite-non-profit-but-with-two-domains?hl=en, time taken: 1.0223841667175293 seconds.
# [LOG] 🚀 Crawling done for https://www.google.com, success: True, time taken: 2.7953341007232666 seconds
# [LOG] 🚀 Content extracted for https://www.google.com, success: True, time taken: 0.01654052734375 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.google.com, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://www.google.com - block index: 0
# [LOG] Extracted 1 blocks from URL: https://www.google.com block index: 0
# [LOG] 🚀 Extraction done for https://www.google.com, time taken: 0.7685754299163818 seconds.
# [LOG] 🚀 Crawling done for https://en.wikipedia.org/wiki/Google, success: True, time taken: 1.9593594074249268 seconds
# [LOG] 🚀 Content extracted for https://en.wikipedia.org/wiki/Google, success: True, time taken: 1.7423975467681885 seconds
# [LOG] 🔥 Extracting semantic blocks for https://en.wikipedia.org/wiki/Google, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 0
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 1
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 2
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 3
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 2
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 4
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 3
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 5
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 1
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 6
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 0
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 7
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 6
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 8
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 7
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 9
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 5
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 10
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 8
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 11
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 4
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 12
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 10
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 13
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 11
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 14
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 12
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 15
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 9
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 16
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 16
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 17
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 15
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 18
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 18
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 19
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 19
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 20
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 20
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 21
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 13
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 22
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 22
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 23
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 23
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 24
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 24
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 25
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 17
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 26
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 21
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 27
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 14
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 28
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 27
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 29
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 28
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 30
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 29
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 31
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 31
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 32
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 32
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 33
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 25
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 34
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 26
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 35
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 34
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 36
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 35
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 37
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 36
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 38
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 33
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 39
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 37
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 40
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 38
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 41
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 30
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 42
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 41
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 43
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 39
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 44
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 44
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 45
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 43
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 46
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 42
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 47
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 40
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 48
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 45
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 49
# [LOG] Extracted 2 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 48
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 50
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 46
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 51
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 50
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 52
# [LOG] Extracted 4 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 49
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Google - block index: 53
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 53
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 47
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 52
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Google block index: 51
# [LOG] 🚀 Extraction done for https://en.wikipedia.org/wiki/Google, time taken: 36.74691557884216 seconds.
# [LOG] 🚀 Crawling done for https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1, success: True, time taken: 1.3378005027770996 seconds
# [LOG] 🚀 Content extracted for https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1, success: True, time taken: 0.04237174987792969 seconds
# [LOG] 🔥 Extracting semantic blocks for https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1 - block index: 0
# [LOG] Call LLM for https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1 - block index: 1
# [LOG] Extracted 1 blocks from URL: https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1 block index: 1
# [LOG] Extracted 1 blocks from URL: https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1 block index: 0
# [LOG] 🚀 Extraction done for https://medium.com/google-cloud/setting-up-google-cloud-identity-for-multinational-companies-4afcbb18dee1, time taken: 1.2866880893707275 seconds.
# [LOG] 🚀 Crawling done for https://www.reuters.com/technology/google, success: True, time taken: 2.290032386779785 seconds
# [ERROR] 🚫 Failed to crawl https://www.reuters.com/technology/google, error: can only concatenate str (not "NoneType") to str
# [LOG] 🚀 Crawling done for https://www.google.com/about/our-company/associated-companies/, success: True, time taken: 0.43924474716186523 seconds
# [LOG] 🚀 Content extracted for https://www.google.com/about/our-company/associated-companies/, success: True, time taken: 0.0 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.google.com/about/our-company/associated-companies/, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://www.google.com/about/our-company/associated-companies/ - block index: 0
# [LOG] Extracted 1 blocks from URL: https://www.google.com/about/our-company/associated-companies/ block index: 0
# [LOG] 🚀 Extraction done for https://www.google.com/about/our-company/associated-companies/, time taken: 2.470973253250122 seconds.
# [LOG] 🚀 Crawling done for https://en.wikipedia.org/wiki/Alphabet_Inc., success: True, time taken: 0.849454402923584 seconds
# [LOG] 🚀 Content extracted for https://en.wikipedia.org/wiki/Alphabet_Inc., success: True, time taken: 0.6406903266906738 seconds
# [LOG] 🔥 Extracting semantic blocks for https://en.wikipedia.org/wiki/Alphabet_Inc., Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 0
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 1
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 2
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 3
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 3
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 4
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 0
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 5
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 1
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 6
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 2
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 7
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 7
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 8
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 6
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 9
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 8
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 10
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 5
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 11
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 11
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 12
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 4
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 13
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 10
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 14
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 14
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 15
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 13
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 16
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 12
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 17
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 9
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 18
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 15
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 19
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 17
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 20
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 18
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 21
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 16
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 22
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 22
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 23
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 23
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 24
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 19
# [LOG] Call LLM for https://en.wikipedia.org/wiki/Alphabet_Inc. - block index: 25
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 21
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 25
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 20
# [LOG] Extracted 1 blocks from URL: https://en.wikipedia.org/wiki/Alphabet_Inc. block index: 24
# [LOG] 🚀 Extraction done for https://en.wikipedia.org/wiki/Alphabet_Inc., time taken: 24.59995126724243 seconds.
# [LOG] 🚀 Crawling done for https://www.bloomberg.com/profile/company/1253793D, success: True, time taken: 4.533987998962402 seconds
# [LOG] 🚀 Content extracted for https://www.bloomberg.com/profile/company/1253793D, success: True, time taken: 0.009427785873413086 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.bloomberg.com/profile/company/1253793D, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://www.bloomberg.com/profile/company/1253793D - block index: 0
# [LOG] Extracted 1 blocks from URL: https://www.bloomberg.com/profile/company/1253793D block index: 0
# [LOG] 🚀 Extraction done for https://www.bloomberg.com/profile/company/1253793D, time taken: 2.678285837173462 seconds.
# [LOG] 🚀 Crawling done for https://www.google.com/about/subsidiaries/, success: True, time taken: 0.411144495010376 seconds
# [LOG] 🚀 Content extracted for https://www.google.com/about/subsidiaries/, success: True, time taken: 0.0 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.google.com/about/subsidiaries/, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://www.google.com/about/subsidiaries/ - block index: 0
# [LOG] Extracted 1 blocks from URL: https://www.google.com/about/subsidiaries/ block index: 0
# [LOG] 🚀 Extraction done for https://www.google.com/about/subsidiaries/, time taken: 1.2669167518615723 seconds.
# [LOG] 🚀 Crawling done for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs, success: True, time taken: 5.86749792098999 seconds
# [LOG] 🚀 Content extracted for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs, success: True, time taken: 0.2897772789001465 seconds
# [LOG] 🔥 Extracting semantic blocks for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 0
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 1
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 2
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 3
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 3
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 4
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 2
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 5
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 1
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 6
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 0
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 7
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 6
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 8
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 7
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 9
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 8
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 10
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 9
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 11
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 11
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 12
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 5
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 13
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 12
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 14
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 14
# [LOG] Call LLM for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs - block index: 15
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 13
# [LOG] Extracted 4 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 4
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 10
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/resource-manager/docs/managing-multiple-orgs block index: 15
# [LOG] 🚀 Extraction done for https://cloud.google.com/resource-manager/docs/managing-multiple-orgs, time taken: 9.00374436378479 seconds.
# [LOG] 🚀 Crawling done for https://cloud.google.com/architecture/identity/best-practices-for-planning, success: True, time taken: 5.174029111862183 seconds
# [LOG] 🚀 Content extracted for https://cloud.google.com/architecture/identity/best-practices-for-planning, success: True, time taken: 1.017989158630371 seconds
# [LOG] 🔥 Extracting semantic blocks for https://cloud.google.com/architecture/identity/best-practices-for-planning, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 0
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 1
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 2
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 3
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 0
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 4
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 2
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 5
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 1
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 6
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 3
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 7
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 4
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 8
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 6
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 9
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 5
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 10
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 9
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 11
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 10
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 12
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 8
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 13
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 7
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 14
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 14
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 15
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 11
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 16
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 16
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 17
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 12
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 18
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 13
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 19
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 19
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 20
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 15
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 21
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 17
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 22
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 18
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 23
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 20
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 24
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 22
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 25
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 21
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 26
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 23
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 27
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 26
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 28
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 25
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 29
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 27
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 30
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 24
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 31
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 30
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 32
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 31
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 33
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 32
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 34
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 28
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 35
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 29
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 36
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 33
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 37
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 36
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 38
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 35
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 39
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 37
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 40
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 38
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 41
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 39
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 42
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 40
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 43
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 42
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 44
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 41
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 45
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 43
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 46
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 45
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 47
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 34
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 48
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 46
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 49
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 44
# [LOG] Call LLM for https://cloud.google.com/architecture/identity/best-practices-for-planning - block index: 50
# [LOG] Extracted 2 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 47
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 50
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 48
# [LOG] Extracted 1 blocks from URL: https://cloud.google.com/architecture/identity/best-practices-for-planning block index: 49
# [LOG] 🚀 Extraction done for https://cloud.google.com/architecture/identity/best-practices-for-planning, time taken: 40.81662583351135 seconds.
# [LOG] 🚀 Crawling done for https://support.google.com/a/answer/12099366?hl=en, success: True, time taken: 3.001159906387329 seconds
# [LOG] 🚀 Content extracted for https://support.google.com/a/answer/12099366?hl=en, success: True, time taken: 0.06910467147827148 seconds
# [LOG] 🔥 Extracting semantic blocks for https://support.google.com/a/answer/12099366?hl=en, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://support.google.com/a/answer/12099366?hl=en - block index: 0
# [LOG] Call LLM for https://support.google.com/a/answer/12099366?hl=en - block index: 1
# [LOG] Call LLM for https://support.google.com/a/answer/12099366?hl=en - block index: 2
# [LOG] Call LLM for https://support.google.com/a/answer/12099366?hl=en - block index: 3
# [LOG] Extracted 1 blocks from URL: https://support.google.com/a/answer/12099366?hl=en block index: 1
# [LOG] Call LLM for https://support.google.com/a/answer/12099366?hl=en - block index: 4
# [LOG] Extracted 1 blocks from URL: https://support.google.com/a/answer/12099366?hl=en block index: 2
# [LOG] Extracted 1 blocks from URL: https://support.google.com/a/answer/12099366?hl=en block index: 3
# [LOG] Extracted 1 blocks from URL: https://support.google.com/a/answer/12099366?hl=en block index: 0
# [LOG] Extracted 1 blocks from URL: https://support.google.com/a/answer/12099366?hl=en block index: 4
# [LOG] 🚀 Extraction done for https://support.google.com/a/answer/12099366?hl=en, time taken: 9.77357816696167 seconds.
# [LOG] 🚀 Crawling done for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf, success: True, time taken: 1.248781442642212 seconds
# [LOG] 🚀 Content extracted for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf, success: True, time taken: 0.07055544853210449 seconds
# [LOG] 🔥 Extracting semantic blocks for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf - block index: 0
# [LOG] Call LLM for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf - block index: 1
# [LOG] Call LLM for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf - block index: 2
# [LOG] Call LLM for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf - block index: 3
# [LOG] Extracted 1 blocks from URL: http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf block index: 2
# [LOG] Call LLM for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf - block index: 4
# [LOG] Extracted 1 blocks from URL: http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf block index: 3
# [LOG] Extracted 1 blocks from URL: http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf block index: 1
# [LOG] Extracted 1 blocks from URL: http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf block index: 0
# [LOG] Extracted 1 blocks from URL: http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf block index: 4
# [LOG] 🚀 Extraction done for http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf, time taken: 2.0210180282592773 seconds.
# [LOG] 🚀 Crawling done for https://icannwiki.org/Google, success: True, time taken: 3.3826863765716553 seconds
# [LOG] 🚀 Content extracted for https://icannwiki.org/Google, success: True, time taken: 0.15280413627624512 seconds
# [LOG] 🔥 Extracting semantic blocks for https://icannwiki.org/Google, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 0
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 1
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 2
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 3
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 2
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 4
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 3
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 5
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 0
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 6
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 1
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 7
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 6
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 8
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 7
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 9
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 5
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 10
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 8
# [LOG] Call LLM for https://icannwiki.org/Google - block index: 11
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 11
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 10
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 4
# [LOG] Extracted 1 blocks from URL: https://icannwiki.org/Google block index: 9
# [LOG] 🚀 Extraction done for https://icannwiki.org/Google, time taken: 10.5013427734375 seconds.
# [LOG] 🚀 Crawling done for https://www.investopedia.com/investing/companies-owned-by-google/, success: True, time taken: 1.5209577083587646 seconds
# [LOG] 🚀 Content extracted for https://www.investopedia.com/investing/companies-owned-by-google/, success: True, time taken: 0.3256356716156006 seconds
# [LOG] 🔥 Extracting semantic blocks for https://www.investopedia.com/investing/companies-owned-by-google/, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 0
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 1
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 2
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 3
# [LOG] Extracted 1 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 1
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 4
# [LOG] Extracted 1 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 3
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 5
# [LOG] Extracted 1 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 2
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 6
# [LOG] Extracted 2 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 5
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 7
# [LOG] Extracted 1 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 0
# [LOG] Call LLM for https://www.investopedia.com/investing/companies-owned-by-google/ - block index: 8
# [LOG] Extracted 1 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 4
# [LOG] Extracted 4 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 6
# [LOG] Extracted 4 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 7
# [LOG] Extracted 1 blocks from URL: https://www.investopedia.com/investing/companies-owned-by-google/ block index: 8
# [LOG] 🚀 Extraction done for https://www.investopedia.com/investing/companies-owned-by-google/, time taken: 5.560008764266968 seconds.

# %%
consolidated_crawl4ai_context_list
# Out:
# ['[\n    {\n        "subsidiaries": [\n            "subsidiaries"\n        ],\n        "associated_domains": [\n            ".charity",\n            ".me"\n        ],\n        "error": false\n    }\n]',
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    }\n]',
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://en.wikipedia.org/wiki/Google",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Waymo",\n            "Sidewalk Labs",\n            "Google DeepMind"\n        ],\n        "associated_domains": [\n            "google.com",\n            "youtube.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Extract subsidiaries and associated domains of the company.",\n        "output_data": {\n            "subsidiaries": [\n                "Adscape",\n                "Android",\n                "Charleston Road Registry",\n                "DeepMind",\n                "Endoxon",\n                "FeedBurner",\n                "Fitbit",\n                "ImageAmerica",\n                "Kaltix",\n                "Nest Labs",\n                "reCAPTCHA",\n                "YouTube",\n                "ZipDash"\n            ],\n            "associated_domains": [\n                "about.google"\n            ]\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Alphabet Inc."\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Raxium"\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "YouTube",\n            "DoubleClick",\n            "Motorola Mobility",\n            "Waze",\n            "DeepMind"\n        ],\n        "associated_domains": [\n            "google.com",\n            "youtube.com",\n            "doubleclick.com",\n            "motorola.com",\n            "waze.com",\n            "deepmind.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Nest",\n            "Google Workspace",\n            "Google Cloud Platform",\n            "Google for Entrepreneurs",\n            "Google Analytics 360 Suite",\n            "Google Fiber",\n            "Project Fi"\n        ],\n        "associated_domains": [\n            "calendar",\n            "weather",\n            "Gmail",\n            "Google Drive",\n            "Google Docs",\n            "Google Sheets",\n            "Google Slides",\n            "BigQuery"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Google generates most of its revenues from advertising. This includes sales of\\napps, purchases made in-app, digital content products on Google and YouTube,\\nAndroid and licensing and service  ...
#  '[\n    {\n        "subsidiaries": [\n            "example.de",\n            "example.es"\n        ],\n        "associated_domains": [\n            "example.com",\n            "example.de",\n            "example.es"\n        ],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Setting up Google Cloud Identity for Multinational Companies",\n        "output_data": {\n            "subsidiaries": [\n                "Brazil",\n                "UK",\n                "Germany",\n                "Spain"\n            ],\n            "associated_domains": [\n                "example.com"\n            ]\n        },\n        "error": false\n    }\n]',
#  None,
#  '[\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "404\\\\. That\\u2019s an error. The requested URL /our-company/associated-companies/ was not found on this\\nserver. That\\u2019s all we know.",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    }\n]',
#  '[\n    {\n        "subsidiaries": [\n            "X Development",\n            "Calico",\n            "Nest",\n            "Verily",\n            "Fiber",\n            "CapitalG",\n            "GV"\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Extract subsidiaries and associated domains of the company.",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://en.wikipedia.org/wiki/Alphabet_Inc.",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Calico",\n            "CapitalG",\n            "Google",\n            "Google Fiber",\n            "GV",\n            "Intrinsic",\n            "Isomorphic Labs",\n            "Verily",\n            "Waymo",\n            "Wing"\n        ],\n        "associated_domains": [\n            "abc.xyz"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Google"\n        ],\n        "associated_domains": [\n            "abc.xyz",\n            "alphabet.com",\n            "abc.com"\n        ],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://en.wikipedia.org/wiki/Alphabet_Inc.",\n        "output_data": {\n            "subsidiaries": [\n                "Loon LLC",\n                "Intrinsic",\n                "Isomorphic Labs"\n            ],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://en.wikipedia.org/wiki/Alphabet_Inc.",\n        "output_data": {\n            "subsidiaries": [\n                "Calico",\n                "CapitalG",\n                "Google",\n                "Google Fiber",\n                "GV",\n                "Intrinsic",\n                "Isomorphic Labs",\n                "Mineral",\n                "Verily",\n                "Waymo",\n                "Wing",\n                "X Development"\n            ],\n            "associated_domains": [\n                "Human health (by overcoming aging)",\n                "Private equity for growth-stage technology companies",\n                "Internet services, largest subsidiary and prior corporate entity name",\n                "Internet access: via fiber",\n                "Venture capital for technology companies",\n                "Robotics software",\n                "Drug discovery",\n                "Sustainable agriculture",\n                "Human health",\n                "Autonomous driving",\n                "Drone-based delivery of freight",\n                "Research and development for \\"moonshot\\" technologies"\n            ]\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Extract subsidiaries and associated domains of the company.",\n        "output_data": {\n            "subsidiaries": [\n                "Google",\n                "Waymo",\n                "Intrinsic",\n                "Mineral",\n                "Jigsaw",\n                "Sidewalk Labs",\n                "GV",\n                "Verily",\n                "Calico",\n                "X Development",\n                "DeepMind",\n                "Google Fiber",\n                "Wing",\n                "Loon",\n                "Chronicle",\n                "CapitalG",\n                "Google Nest"\n   ...
#  '[\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://www.bloomberg.com/profile/company/1253793D",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    }\n]',
#  '[\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "404\\\\. That\\u2019s an error. The requested URL /subsidiaries/ was not found on this server. That\\u2019s all we\\nknow.",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    }\n]',
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": [\n                "cloud.google.com",\n                "gstatic.com",\n                "devrel-devsite",\n                "google.com"\n            ]\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/resource-manager/docs/managing-multiple-orgs",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "2. Select the organization resource you want to edit: 1. Click the project drop-down list at the top of the page. 2. In the Select from dialog, click the organization drop-down list, and select the organization resource to which you want to add an Organization Administrator. 3. On the list that appears, click the organization resource to open its IAM Permissions page. 3. Click Add, and then enter the email address of one or more users you want to set as Organization Administrators. 4. In the Select a role drop-down list, select Resource Manager > Organization Administrator, and then click Save. The Organization Administrator can do the following: * Take full control of the organization resource. Separation of responsibilities between Google Workspace or Cloud Identity super administrator and Google Cloud administrator is established. * Delegate responsibility over critical functions by assigning the relevant IAM roles. ### Create folders for sub-organizations Create a folder under the organization resource for each sub-organization. To create folders, you must have the Folder Admin or Folder Creator role at the parent level. For example, to create folders at the organization level, you must have one of these roles at the organization level. As part of creating a folder, you must assign it a name. Folder na ...
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "cloud.google.com",\n            "gstatic.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "SAP on Google Cloud",\n            "Windows on Google Cloud",\n            "Red Hat on Google Cloud"\n        ],\n        "associated_domains": [\n            "cloud.google.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "cloud.google.com",\n            "gstatic.com"\n        ],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/architecture/identity/best-practices-for-planning",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": [\n                "cloud.google.com",\n                "gstatic.com"\n            ]\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/architecture/identity/best-practices-for-planning",\n        "output_data": {\n            "subsidiaries": [\n                "Vertex AI Platform",\n                "Vertex AI Studio",\n                "Vertex AI Agent Builder",\n                "Dialogflow",\n                "Natural Language AI",\n                "Speech-to-Text",\n                "Text-to-Speech",\n                "Translation AI",\n                "Document AI",\n                "Vision AI",\n                "Contact Center AI",\n                "Looker",\n                "Looker Studio",\n                "Compute Engine",\n                "App Engine",\n                "Cloud GPUs",\n                "Migrate to Virtual Machines",\n                "Spot VMs",\n                "Batch",\n                "Sole-Tenant Nodes",\n                "Bare Metal",\n                "Recommender",\n                "VMware Engine",\n                "Cloud Run"\n            ],\n            "associated_domains": [\n                "https://www.gstatic.com/cloud/images/navigation/forward.svg"\n            ]\n        },\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://cloud.google.com/architecture/identity/best-practices-for-planning",\n        "output_data": {\n            "subsidiaries": [\n                "Config Connector",\n                "Active Assist",\n                "Earth Engine",\n                "Google Maps Platform",\n                "Cloud CDN",\n                "Live Stream API",\n                "OpenCue",\n                "Transcoder API",\n                "Video Stitcher API",\n                "Migration Center",\n                "Application Migration",\n                "Migrate to Virtual Machines",\n                "Cloud Foundation Toolkit",\n                "Database Migration Service",\n                "Migrate to Containers",\n                "BigQuery Data Transfer Service",\n                "Rapid Migration and Modernization Program",\n                "Transfer Appliance",\n                "Storage Transfer Service",\n                "VMware Engine",\n                "Immersive Stream for XR",\n                "Cloud Armor"\n            ],\n            "associated_domains": [\n                "cloud.google.com"\n            ]\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Cloud CDN",\n            "Media CDN",\n            "Cloud DNS",\n            "Cloud Load Balancing",\n            "Cloud NAT",\n            "Cloud Connectivity",\n            "Network Connectivity Center",\n   ...
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "example.com",\n            "solarmora.com",\n            "temp.example.com",\n            "temp.yourdomain.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "example.com",\n            "temp.example.com",\n            "solarmora.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "example.com",\n            "temp.example.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "solarmora.com",\n            "example.com"\n        ],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "3. Switch your primary domain from temp.example.com to example.com. Note: Don\\\\\\\\\'t delete the temp.example.com domain. ![\\\\\\\\\\\\\\"\\\\\\\\\\\\\\"](\\\\\\\\\\\\\\"//storage.googleapis.com/support-kms-\\nprod/X8guxJLUodXk0yazheqfvaioBoerIAc28EPx\\\\\\\\\\\\\\")   4. Update each user\\\\\\\\\'s address to use example.com as the domain for their primary email. ![\\\\\\\\\\\\\\"\\\\\\\\\\\\\\"](\\\\\\\\\\\\\\"//storage.googleapis.com/support-kms-\\nprod/Ce41q2bHVIXK7JuOZHz1f8EUBvUasFxJLP0f\\\\\\\\\\\\\\")   5. Help users upload any files to Drive, and update their user password. Now users have accounts and their data at example.com.   6. (Optional): Remove the secondary domain, temp.example.com, from your Google Workspace account. ## Related articles   * Add a secondary domain\\n  * Change your primary domain\\n  * Remove a domain\\n  * Merge domains from separate accounts Give feedback about this article Choose a section to give feedback on ## Was this helpful? How can we improve it? YesNo Submit ## Need more help? ### Try these next steps: Post to the help community Get answers from community members Contact us Tell us more and we\\u2019ll help you get there true ## Split or merge domains   * 1 of 3 Merge domains from separate accounts   * 2 of 3 Separate a Google Workspace account into two accounts   * 3 of 3 Google Workspace Domain Transfer ![\\\\\\\\\\\\\\"\\\\\\\\\\\\\\"](\\\\\\\\\\\\\\"https://lh3.googleusercontent.com/exxMjxadqER4Ie3_TMeBqZfSwNBfL_3tU0Xvn4tJ3_POtw4haXNbIx7OL7v52_DcaBpe=w96\\\\\\\\\\\\\\"/) Start your free 14-day trial today Professional email, online storage, shared calendars, video meetings and more.\\nStart your free Google Workspace trial today.   * \\u00a92024 Google \\n  * Privacy Policy\\n  * Terms of Service Deutsch\\u200eespa\\u00f1ol\\u200efran\\u00e7ais\\u200eIndonesia\\u200eitaliano\\u200eNederlands\\u200epolski\\u200eportugu\\u00eas\\n(Brasil)\\u200esvenska\\u200eTi\\u1ebfng\\nVi\\u1ec7t\\u200eT\\u00fcrk\\u00e7e\\u200e\\u0440\\u0443\\u0441\\u0441\\u043a\\u0438\\u0439\\u200e\\u0443\\u043a\\u0440\\u0430\\u0457\\u043d\\u0441\\u044c\\u043a\\u0430\\u200e\\u200f\\u05e2\\u05d1\\u05e8\\u05d9\\u05ea\\u200f\\u0627\\u0644\\u0639\\u0631\\u0628\\u064a\\u0629\\u0e44\\u0e17\\u0e22\\u200e\\u4e2d\\u6587\\uff08\\u7b80\\u4f53\\uff09\\u200e\\u4e2d\\u6587\\uff08\\u7e41\\u9ad4\\uff09\\u200e\\u65e5\\u672c\\u8a9e\\u200e\\ud55c\\uad6d\\uc5b4\\u200e\\nEnglish\\u200e English\\u200e   1. Deutsch\\u200e\\n  2. espa\\u00f1ol\\u200e\\n  3. fran\\u00e7ais\\u200e\\n  4. Indonesia\\u200e\\n  5. italiano\\u200e\\n  6. Nederlands\\u200e\\n  7. polski\\u200e\\n  8. portugu\\u00eas (Brasil)\\u200e\\n  9. svenska\\u200e\\n  10. Ti\\u1ebfng Vi\\u1ec7t\\u200e\\n  11. T\\u00fcrk\\u00e7e\\u200e\\n  12. \\u0440\\u0443\\u0441\\u0441\\u043a\\u0438\\u0439\\u200e\\n  13. \\u0443\\u043a\\u0440\\u0430\\u0457\\u043d\\u0441\\u044c\\u043a\\u0430\\u200e\\n  14. \\u200f\\u05e2\\u05d1\\u05e8\\u05d9\\u05ea\\n  15. \\u200f\\u0627\\u0644\\u0639\\u0631\\u0628\\u064a\\u0629\\n  16. \\u0e44\\u0e17\\u0e22\\u200e\\n  17. \\u4e2d\\u6587\\uff08\\u7b80\\u4f53\\uff09\\u200e\\ ...
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "example.com",\n            "temp.example.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "example.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "example.com",\n            "solarmora.com",\n            "temp.example.com",\n            "temp.yourdomain.com"\n        ],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "http://www.google.com/support/enterprise/static/gapps/docs/admin/en/nftf/multiple_domains/gapps_%20multiple_domains.pdf",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": [\n                "solarmora.com",\n                "example.com"\n            ]\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "temp.example.com",\n            "example.com"\n        ],\n        "error": false\n    }\n]',
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Charleston Road Registry Inc."\n        ],\n        "associated_domains": [\n            ".google",\n            ".youtube",\n            ".docs",\n            ".lol",\n            ".drive",\n            ".search",\n            ".play",\n            "\\u062c\\u0648\\u062c\\u0644.\\u0634\\u0628\\u0643\\u0629"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "www.google.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            ".com",\n            ".net",\n            ".org",\n            ".biz",\n            ".info",\n            ".name",\n            ".pro",\n            ".app",\n            ".day",\n            ".dev",\n            ".how",\n            ".page"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            ".cloud",\n            ".app",\n            ".search",\n            ".blog"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            ".ie"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            ".BLOG",\n            ".MUSIC",\n            ".CLOUD",\n            ".film",\n            ".movie",\n            ".mov",\n            ".live",\n            ".show",\n            ".tube",\n            ".app",\n            ".search"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            "Registry.Google",\n            ".LOL",\n            ".YouTube"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Deja Usenet",\n            "Blogger.com",\n            "Urchin",\n            "Writely",\n            "Android",\n            "JotSpot",\n            "Doubleclick",\n            "Aardvark",\n            "YouTube",\n            "Picnik",\n            "Admob",\n            "reCaptcha",\n            "Slide",\n            "ITA Software"\n        ],\n        "associated_domains": [\n            "g.co",\n            "g.co.uk",\n            "goggle.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [\n            ".app",\n            ".baby",\n            ".blog",\n            ".book",\n            ".buy",\n            ".cloud",\n            ".corp",\n            ".cpa",\n            ".dds",\n            ".dev",\n            ".diy",\n            ".docs",\n            ".dog",\n            ".dot",\n            ".drive",\n            ".earth",\n            ".family",\n            ".film",\n            ".free",\n            ".fun",\n            ".fyi",\n            ".game",\n            ".gmbh",\n            ".goo",\n            ".home",\n            ".inc",\n            ".live",\n            ".llc",\n            ".llp",\n            ".lol",\n            ".love",\n            ".mail",\n            ".map",\n            ".mba",\n            ".med",\n            ".mom",\n            ".moto",\n            ".movie",\n            ".music",\n            ".pet",\n            ".phd",\n            ".play",\n            ".plus",\n            ".search",\n            ".shop",\n            ".show",\n            ".site",\n            ".spot",\n            ".srl",\n            ".store",\n            ".talk",\n            ".team",\n            ".tech",\n            ".tube",\n            ".vip",\n            ".web",\n            ".wow",\n            ".you",\n            ".ads",\n            ".and",\n            ".android",\n            ".are",\n            ".boo",\n            ".c ...
#  '[\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Mandiant",\n            "Fitbit",\n            "Looker",\n            "Nest",\n            "Waze",\n            "DoubleClick",\n            "YouTube"\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://www.investopedia.com/investing/companies-owned-by-google/",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Mandiant"\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Fitbit"\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "YouTube",\n            "Google Fiber",\n            "Nest Labs",\n            "DoubleClick",\n            "Fitbit",\n            "Looker",\n            "Waze",\n            "Chronicle",\n            "DeepMind",\n            "GV",\n            "CapitalG",\n            "Verily",\n            "Waymo",\n            "Wing",\n            "Loon",\n            "Sidewalk Labs",\n            "Calico"\n        ],\n        "associated_domains": [\n            "youtube.com",\n            "googlefiber.net",\n            "nest.com",\n            "doubleclick.net",\n            "fitbit.com",\n            "looker.com",\n            "waze.com",\n            "chronicle.security",\n            "deepmind.com",\n            "gv.com",\n            "capitalg.com",\n            "verily.com",\n            "waymo.com",\n            "wing.com",\n            "loon.com",\n            "sidewalklabs.com",\n            "calicolabs.com"\n        ],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Alphabet Inc. (GOOGL), the parent company of Google, owns several other companies in addition to the search engine giant. Seven major companies owned by Alphabet are YouTube, Waze, DoubleClick, Nest, Looker, Fitbit, and Mandiant.",\n        "output_data": {\n            "subsidiaries": [\n                "YouTube",\n                "Waze",\n                "DoubleClick",\n                "Nest",\n                "Looker",\n                "Fitbit",\n                "Mandiant"\n            ],\n            "associated_domains": [\n                "search engine",\n                "advertising",\n                "hardware",\n                "software"\n            ]\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Looker"\n        ],\n        "associated_domains": [\n            "Business intelligence software",\n            "data analytics"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Nest"\n        ],\n        "associated_domains": [\n            "Smart-home products"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Waze"\n        ],\n        "associated_domains": [\n            "Mobile navigation app"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "DoubleClick"\n        ],\n        "associated_domains": [\n            "Ad management",\n            "ad-serving solutions"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "DoubleClick"\n        ],\n        "associated_domains": [\n            "advertising"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "YouTube"\n        ],\n        "associated_domains": [\n            "video-sharing platform"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n             ...

# %%
# write in txt file
with open('consolidated_crawl4ai_context_list_latest.txt', 'w') as f:
    for item in consolidated_crawl4ai_context_list:
        f.write("%s\n" % item)

# %%
# convert list to string
consolidated_crawl4ai_context_list_str = ' '.join(str(item) for item in consolidated_crawl4ai_context_list if item is not None)

# %%
consolidated_crawl4ai_context_list_str
# Out:
# '[\n    {\n        "subsidiaries": [\n            "subsidiaries"\n        ],\n        "associated_domains": [\n            ".charity",\n            ".me"\n        ],\n        "error": false\n    }\n] [\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    }\n] [\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "https://en.wikipedia.org/wiki/Google",\n        "output_data": {\n            "subsidiaries": [],\n            "associated_domains": []\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Waymo",\n            "Sidewalk Labs",\n            "Google DeepMind"\n        ],\n        "associated_domains": [\n            "google.com",\n            "youtube.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "model_name": "Subsidiaries and Associated Domains Extractor",\n        "input_data": "Extract subsidiaries and associated domains of the company.",\n        "output_data": {\n            "subsidiaries": [\n                "Adscape",\n                "Android",\n                "Charleston Road Registry",\n                "DeepMind",\n                "Endoxon",\n                "FeedBurner",\n                "Fitbit",\n                "ImageAmerica",\n                "Kaltix",\n                "Nest Labs",\n                "reCAPTCHA",\n                "YouTube",\n                "ZipDash"\n            ],\n            "associated_domains": [\n                "about.google"\n            ]\n        },\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Alphabet Inc."\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Raxium"\n        ],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "YouTube",\n            "DoubleClick",\n            "Motorola Mobility",\n            "Waze",\n            "DeepMind"\n        ],\n        "associated_domains": [\n            "google.com",\n            "youtube.com",\n            "doubleclick.com",\n            "motorola.com",\n            "waze.com",\n            "deepmind.com"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [\n            "Nest",\n            "Google Workspace",\n            "Google Cloud Platform",\n            "Google for Entrepreneurs",\n            "Google Analytics 360 Suite",\n            "Google Fiber",\n            "Project Fi"\n        ],\n        "associated_domains": [\n            "calendar",\n            "weather",\n            "Gmail",\n            "Google Drive",\n            "Google Docs",\n            "Google Sheets",\n            "Google Slides",\n            "BigQuery"\n        ],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\n    },\n    {\n        "subsidiaries": [],\n        "associated_domains": [],\n        "error": false\ ...

# %%
# AI Agrent to Extrct Subsidiaries and Associated Domains

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser

# %%
prompt_final_response_format="""You are an AI Agent. Your task is to extract the subsidiaries and associated domains of the company.\n
Output format should be given json format:{"subsidiaries":["subsidiaries1","subsidiaries2",...], "associated_domains": ["associated_domain_1","associated_domain_2",....]}.Make sure keys are subsidiaries and associated_domains.\n"""

# %%
class OpenAIModel:
    def __init__(self):
        self.model_id = "gpt-4o"
    def gpt_model_call_without_chain(self,prompt,context):
        messages = [
            (
        "system",
        prompt,
        ),
    ("human", context),
    ]
        llm = ChatOpenAI(model=self.model_id, temperature=0,max_tokens=4000)
        response = llm.invoke(messages)
        response_explainbility =response.content
        return response_explainbility

# %%
obj_openai = OpenAIModel()
response = obj_openai.gpt_model_call_without_chain(prompt_final_response_format,consolidated_crawl4ai_context_list_str)

# %%
if response.startswith("```json"):
    subsidiaries_associated_domain = json.loads(response.replace('```json\n', '').replace('\n```', ''))
else:
    subsidiaries_associated_domain = json.loads(response)

# %%
with open('subsidiaries_associated_domain_latest.json', 'w') as f:
    json.dump(subsidiaries_associated_domain, f,indent=4)

# %%
# Define your desired data structure.
class SubsidiaryWithDomains(BaseModel):
    output: str = Field(description="""{"subsidiaries": ["subsidiaries1", "subsidiaries2", ...], "associated_domains": ["associated_domain_1", "associated_domain_2", ...]}""")

# %%
# final_prompt = ChatPromptTemplate.from_messages(
#     [
#         (
#             "system",
#             """You are an AI Agent. Your task is to extract the subsidiaries and associated domains of the company.
#             output format should be like this: {"subsidiaries":["subsidiaries1","subsidiaries2",...], "associated_domains": ["associated_domain_1","associated_domain_2",....]}""",
#         ),
#         ("human", "For company: {company_name} Extract the subsidiaries and associated domains and context from where to extract is {consolidated_crawl4ai_context_list_str}"),
#     ]
# )

# %%
parser = JsonOutputParser(pydantic_object=SubsidiaryWithDomains)


final_prompt = PromptTemplate(
    template="You are an AI Agent. Your task is to extract the subsidiaries and associated domains of the company.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

# %%
# ChatPromptTemplate(template_format="Answer")

# %%
# final_prompt

# %%
llm_final = ChatOpenAI(model=openai_model, temperature=0, max_tokens=2048,max_retries=5)
chain_final = final_prompt | llm_final | parser
# chain_final_response = chain_final.invoke(
#     {
#         "company_name": company_name,
#         "consolidated_crawl4ai_context_list_str": consolidated_crawl4ai_context_list_str
#     }
# )

chain_final_response = chain_final.invoke({"query": f"For company: {company_name} Extract the subsidiaries and associated domains and context from where to extract is {consolidated_crawl4ai_context_list_str}"})

# %%
chain_final_response
# Out:
# {'output': '{"subsidiaries": ["Waymo", "Sidewalk Labs", "Google DeepMind", "Adscape", "Android", "Charleston Road Registry", "DeepMind", "Endoxon", "FeedBurner", "Fitbit", "ImageAmerica", "Kaltix", "Nest Labs", "reCAPTCHA", "YouTube", "ZipDash", "Alphabet Inc.", "Raxium", "DoubleClick", "Motorola Mobility", "Waze", "Google Workspace", "Google Cloud Platform", "Google for Entrepreneurs", "Google Analytics 360 Suite", "Google Fiber", "Project Fi", "AdMob", "AdSense", "Pyra Labs", "Currents (news app)", "Green Throttle Games", "Owlchemy Labs", "Oyster", "PaperofRecord.com", "Podcasts", "Quick, Draw!", "Santa Tracker", "Songza", "Stadia", "Typhoon Studios", "TV", "Vevo", "Video", "Books", "Games", "Music", "Newsstand", "Pass", "Services", "BandPage", "BrandConnect", "Content ID", "Instant", "Kids", "Music", "Official channel", "Preferred", "Premium", "YouTube Rewind", "RightsFlow", "Shorts", "Studio", "TV", "Allo", "Bump", "Buzz", "Chat", "Contacts", "Currents (social app)", "Dodgeball", "Duo", "Fi Wireless", "Friend Connect", "Gizmo5", "Google+", "Gmail", "Groups", "Hangouts", "Helpouts", "IME", "Jaiku", "Marratech", "Meebo", "Meet", "Messages", "Moderator", "Neotonic Software", "Orkut", "Postini", "Quest Visual", "Schemer", "Spaces", "Sparrow", "Talk", "Translate", "Voice", "Voice Local Search", "Wave", "Anvato", "Apigee", "Bitium", "Chronicle", "VirusTotal", "Compute Engine", "Connect", "Dataflow", "Datastore", "Kaggle", "Looker", "Mandiant", "Messaging", "Orbitera", "Shell", "Stackdriver", "Storage", "Camera", "Lens", "Snapseed", "Nik Software", "Panoramio", "Photos", "Picasa", "Web Albums", "Picnik", "Android Dev Phone", "Android One", "Nexus", "Nexus One", "S", "Galaxy Nexus", "4", "5", "6", "5X", "6P", "Pixel", "Pixel 2", "Pixel 3", "Pixel 3a", "Pixel 4", "Pixel 4a", "Pixel 5", "Pixel 5a", "Pixel 6", "Pixel 6a", "Pixel 7", "Pixel 7a", "Pixel Fold", "Pixel 8", "Pixel 8a", "Pixel 9", "Pixel 9 Pro Fold", "Play Edition", "Project Ara", "Chromebook", "Nexus 7 (2012)", "Nexus 7 (2013)", "Nexus 10", "Nexus 9", "Chromebook Pixel", "Pixelbook", "Pixelbook Go", "Pixel C", "Pixel Slate", "Pixel Tablet", "Pixel Buds", "Pixel Watch", "Pixel Watch 2", "Pixel Watch 3", "Project Iris (unreleased)", "Cardboard", "Contact Lens", "Daydream", "Glass", "Aardvark", "BeatThatQuote.com", "Kaltix", "Like.com", "Metaweb", "Freebase", "Endoxon", "ImageAmerica", "Adscape", "Invite Media", "Urchin", "PostRank", "Wildfire Interactive", "Widevine", "Softcard", "Google Fiber", "Calico", "CapitalG", "Firebase", "Tenor", "GV", "Isomorphic Labs", "Verily", "X Development", "Wing", "Google Inc.", "Ads", "AI", "Brain", "Android", "booting process", "recovery mode", "software development", "version history", "China", "Goojje", "Chrome", "Cloud", "Glass", "Google.org", "Crisis Response", "Public Alerts", "RechargeIT", "Health", "Maps", "Pixel", "Search", "Timeline", "Sustainability", "History", "Me at the zoo", "Social impact", "YouTuber", "Access", "Google Fiber", "DeepMind", "DoubleClick", "Fitbit", "Tenor", "Waze", "YouTube", "AlphaFold", "AlphaGo", "AlphaGo Zero", "AlphaStar", "AlphaZero", "Master", "MuZero", "WaveNet", "Baseline Study", "Loon LLC", "Intrinsic", "Isomorphic Labs", "Calico", "CapitalG", "Google", "Google Fiber", "GV", "Intrinsic", "Mineral", "Verily", "Waymo", "Wing", "X Development", "Google", "Waymo", "Intrinsic", "Mineral", "Jigsaw", "Sidewalk Labs", "GV", "Verily", "Calico", "X Development", "DeepMind", "Google Fiber", "Wing", "Loon", "Chronicle", "CapitalG", "Google Nest", "Google Inc.", "Waymo", "Charleston Road Registry Inc.", "Google China", "Google.org", "Mandiant", "Fitbit", "Looker", "Nest", "Waze", "DoubleClick", "YouTube"], "associated_domains": ["google.com", "youtube.com", "about.google", "calendar", "weather", "Gmail", "Google Drive", "Google Docs", "Google Sheets", "Google Slides", "BigQuery", "android.com", "googlecloud.com", "gmail.com", "google.com/calendar", "maps.google.com", "drive.google.com", "docs.google.com", "sheet ...

# %%
type(chain_final_response)
# Out:
# dict

# %%
# dict to json
chain_final_response_json = json.dumps(chain_final_response, indent=4)

# %%
print(chain_final_response_json)
# Out:
# {
#     "output": "{\"subsidiaries\": [\"Waymo\", \"Sidewalk Labs\", \"Google DeepMind\", \"Adscape\", \"Android\", \"Charleston Road Registry\", \"DeepMind\", \"Endoxon\", \"FeedBurner\", \"Fitbit\", \"ImageAmerica\", \"Kaltix\", \"Nest Labs\", \"reCAPTCHA\", \"YouTube\", \"ZipDash\", \"Alphabet Inc.\", \"Raxium\", \"DoubleClick\", \"Motorola Mobility\", \"Waze\", \"Google Workspace\", \"Google Cloud Platform\", \"Google for Entrepreneurs\", \"Google Analytics 360 Suite\", \"Google Fiber\", \"Project Fi\", \"AdMob\", \"AdSense\", \"Pyra Labs\", \"Currents (news app)\", \"Green Throttle Games\", \"Owlchemy Labs\", \"Oyster\", \"PaperofRecord.com\", \"Podcasts\", \"Quick, Draw!\", \"Santa Tracker\", \"Songza\", \"Stadia\", \"Typhoon Studios\", \"TV\", \"Vevo\", \"Video\", \"Books\", \"Games\", \"Music\", \"Newsstand\", \"Pass\", \"Services\", \"BandPage\", \"BrandConnect\", \"Content ID\", \"Instant\", \"Kids\", \"Music\", \"Official channel\", \"Preferred\", \"Premium\", \"YouTube Rewind\", \"RightsFlow\", \"Shorts\", \"Studio\", \"TV\", \"Allo\", \"Bump\", \"Buzz\", \"Chat\", \"Contacts\", \"Currents (social app)\", \"Dodgeball\", \"Duo\", \"Fi Wireless\", \"Friend Connect\", \"Gizmo5\", \"Google+\", \"Gmail\", \"Groups\", \"Hangouts\", \"Helpouts\", \"IME\", \"Jaiku\", \"Marratech\", \"Meebo\", \"Meet\", \"Messages\", \"Moderator\", \"Neotonic Software\", \"Orkut\", \"Postini\", \"Quest Visual\", \"Schemer\", \"Spaces\", \"Sparrow\", \"Talk\", \"Translate\", \"Voice\", \"Voice Local Search\", \"Wave\", \"Anvato\", \"Apigee\", \"Bitium\", \"Chronicle\", \"VirusTotal\", \"Compute Engine\", \"Connect\", \"Dataflow\", \"Datastore\", \"Kaggle\", \"Looker\", \"Mandiant\", \"Messaging\", \"Orbitera\", \"Shell\", \"Stackdriver\", \"Storage\", \"Camera\", \"Lens\", \"Snapseed\", \"Nik Software\", \"Panoramio\", \"Photos\", \"Picasa\", \"Web Albums\", \"Picnik\", \"Android Dev Phone\", \"Android One\", \"Nexus\", \"Nexus One\", \"S\", \"Galaxy Nexus\", \"4\", \"5\", \"6\", \"5X\", \"6P\", \"Pixel\", \"Pixel 2\", \"Pixel 3\", \"Pixel 3a\", \"Pixel 4\", \"Pixel 4a\", \"Pixel 5\", \"Pixel 5a\", \"Pixel 6\", \"Pixel 6a\", \"Pixel 7\", \"Pixel 7a\", \"Pixel Fold\", \"Pixel 8\", \"Pixel 8a\", \"Pixel 9\", \"Pixel 9 Pro Fold\", \"Play Edition\", \"Project Ara\", \"Chromebook\", \"Nexus 7 (2012)\", \"Nexus 7 (2013)\", \"Nexus 10\", \"Nexus 9\", \"Chromebook Pixel\", \"Pixelbook\", \"Pixelbook Go\", \"Pixel C\", \"Pixel Slate\", \"Pixel Tablet\", \"Pixel Buds\", \"Pixel Watch\", \"Pixel Watch 2\", \"Pixel Watch 3\", \"Project Iris (unreleased)\", \"Cardboard\", \"Contact Lens\", \"Daydream\", \"Glass\", \"Aardvark\", \"BeatThatQuote.com\", \"Kaltix\", \"Like.com\", \"Metaweb\", \"Freebase\", \"Endoxon\", \"ImageAmerica\", \"Adscape\", \"Invite Media\", \"Urchin\", \"PostRank\", \"Wildfire Interactive\", \"Widevine\", \"Softcard\", \"Google Fiber\", \"Calico\", \"CapitalG\", \"Firebase\", \"Tenor\", \"GV\", \"Isomorphic Labs\", \"Verily\", \"X Development\", \"Wing\", \"Google Inc.\", \"Ads\", \"AI\", \"Brain\", \"Android\", \"booting process\", \"recovery mode\", \"software development\", \"version history\", \"China\", \"Goojje\", \"Chrome\", \"Cloud\", \"Glass\", \"Google.org\", \"Crisis Response\", \"Public Alerts\", \"RechargeIT\", \"Health\", \"Maps\", \"Pixel\", \"Search\", \"Timeline\", \"Sustainability\", \"History\", \"Me at the zoo\", \"Social impact\", \"YouTuber\", \"Access\", \"Google Fiber\", \"DeepMind\", \"DoubleClick\", \"Fitbit\", \"Tenor\", \"Waze\", \"YouTube\", \"AlphaFold\", \"AlphaGo\", \"AlphaGo Zero\", \"AlphaStar\", \"AlphaZero\", \"Master\", \"MuZero\", \"WaveNet\", \"Baseline Study\", \"Loon LLC\", \"Intrinsic\", \"Isomorphic Labs\", \"Calico\", \"CapitalG\", \"Google\", \"Google Fiber\", \"GV\", \"Intrinsic\", \"Mineral\", \"Verily\", \"Waymo\", \"Wing\", \"X Development\", \"Google\", \"Waymo\", \"Intrinsic\", \"Mineral\", \"Jigsaw\", \"Sidewalk Labs\", \"GV\", \"Verily\", \"Calico\", \"X Development\", \"DeepMind\",  ...
# }

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "unininstall" - maybe you meant "uninstall"
